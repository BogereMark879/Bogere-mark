# %% [markdown]
# <a href="https://colab.research.google.com/github/BogereMark879/Bogere-mark/blob/main/Traffic_Jam_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
data= pd.read_csv('/content/drive/MyDrive/traffic.csv')
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['Vehicles'].plot(kind='hist', bins=20, title='Vehicles')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['ID'].plot(kind='hist', bins=20, title='ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_11.groupby('DateTime').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12.plot(kind='scatter', x='Vehicles', y='ID', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['DateTime']
#   ys = series['Vehicles']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('DateTime', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('DateTime')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='DateTime', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DateTime')
# _ = plt.ylabel('Vehicles')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['DateTime']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'DateTime'}, axis=1)
#               .sort_values('DateTime', ascending=True))
#   xs = counted['DateTime']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('DateTime', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('DateTime')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='DateTime', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('DateTime')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Junction']
#   ys = series['Vehicles']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('Junction', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('DateTime')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='DateTime', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Junction')
# _ = plt.ylabel('Vehicles')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Junction']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Junction'}, axis=1)
#               .sort_values('Junction', ascending=True))
#   xs = counted['Junction']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_16.sort_values('Junction', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('DateTime')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='DateTime', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Junction')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_17['Vehicles'].plot(kind='line', figsize=(8, 4), title='Vehicles')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['ID'].plot(kind='line', figsize=(8, 4), title='ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['DateTime'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='Vehicles', y='DateTime', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['DateTime'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='ID', y='DateTime', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
data["DateTime"]= pd.to_datetime(data["DateTime"])
data = data.drop(["ID"], axis=1) #dropping IDs
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %%
#df to be used for EDA
df=data.copy()
#Let's plot the Timeseries
colors = [ "#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
plt.figure(figsize=(20,4),facecolor="#FFEBCD")
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Traffic On Junctions Over Years")
Time_series.set_ylabel("Number of Vehicles")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
#Exploring more features
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %%
#Let's plot the Timeseries
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,2),facecolor="#FFEBCD")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=colors )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(12,5),facecolor="#FFEBCD")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years")
count.set_ylabel("Number of Vehicles")
count.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
corrmat = df.corr()
plt.subplots(figsize=(10,10),facecolor="#FFEBCD")
sns.heatmap(corrmat,cmap= "Pastel2",annot=True,square=True, )
# Out:
# <Axes: >

# %%
sns.pairplot(data=df, hue= "Junction",palette=colors)

# %%
#Pivoting data fron junction
df_J = data.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)

#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#FFEBCD", sharey=True)
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")


#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %%
#Normalizing and Differencing to make the series stationary
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary")


#Checking if the series is stationary

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]]
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.265303390415337
# p-value: 4.79853987639816e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.795891026940065
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.001759908832316
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.979092563052276
# p-value: 2.778787532595421e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len]
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %%
# Model for the prediction
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001, patience=10, restore_best_weights=True)

    # The GRU model
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))

    # Compiling the model using legacy SGD optimizer
    model.compile(optimizer=tensorflow.keras.optimizers.legacy.SGD(decay=1e-7, momentum=0.9), loss='mean_squared_error')
    model.fit(X_Train, y_Train, epochs=50, batch_size=150, callbacks=[early_stopping])
    pred_GRU = model.predict(X_Test)
    return pred_GRU

# To calculate the root mean squared error in predictions
def RMSE_Value(test, predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

# To plot the comparative plot of targets and predictions
def PredictionsPlot(test, predicted, m):
    plt.figure(figsize=(12, 5), facecolor="#FFEBCD")
    plt.plot(test, color=colors[m], label="True Value", alpha=0.5)
    plt.plot(predicted, color="#627D78", label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0750
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 379ms/step - loss: 0.0750
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0673
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 381ms/step - loss: 0.0673
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0660
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 382ms/step - loss: 0.0660
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0633
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 382ms/step - loss: 0.0633
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0625
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 383ms/step - loss: 0.0625
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0610
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 37s 423ms/step - loss: 0.0610
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0594
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 377ms/step - loss: 0.0594
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0591
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 34s 385ms/step - loss: 0.0591
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0577
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 34s 384ms/step - loss: 0.0577
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0575
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 379ms/step - loss: 0.0575
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0564
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 385ms/step - loss: 0.0564
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0561
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 383ms/step - loss: 0.0561
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0555
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 36s 421ms/step - loss: 0.0555
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0552
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 374ms/step - loss: 0.0552
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0544
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 385ms/step - loss: 0.0544
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0538
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 382ms/step - loss: 0.0538
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0534
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 382ms/step - loss: 0.0534
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0528
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 377ms/step - loss: 0.0528
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0524
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 381ms/step - loss: 0.0524
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0522
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 384ms/step - loss: 0.0522
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0518
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 36s 417ms/step - loss: 0.0518
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0520
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 381ms/step - loss: 0.0520
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0512
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 380ms/step - loss: 0.0512
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0512
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 380ms/step - loss: 0.0512
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 380ms/step - loss: 0.0505
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 365ms/step - loss: 0.0505
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0505
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0498
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0498
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 35s 400ms/step - loss: 0.0505
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 382ms/step - loss: 0.0493
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0490
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 372ms/step - loss: 0.0490
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0492
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 366ms/step - loss: 0.0492
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0491
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0491
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0494
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0494
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0491
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0491
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 372ms/step - loss: 0.0488
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 34s 396ms/step - loss: 0.0489
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0489
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0485
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 383ms/step - loss: 0.0485
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0495
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 382ms/step - loss: 0.0495
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0476
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 371ms/step - loss: 0.0476
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0482
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0484
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0484
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0481
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0481
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0484
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 34s 396ms/step - loss: 0.0484
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0475
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0475
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0477
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 371ms/step - loss: 0.0477
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0477
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 375ms/step - loss: 0.0477
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0476
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 379ms/step - loss: 0.0476
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0472
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 381ms/step - loss: 0.0472
# 45/45 [==============================] - 4s 40ms/step

# %%
#Results for J1
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.24572659701304073.

# %%
#Predictions For Second Junction
PredJ2 = GRU_model(X_trainJ2,y_trainJ2,X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2361
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 57s 489ms/step - loss: 0.2361
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 40s 454ms/step - loss: 0.2043
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1968
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 426ms/step - loss: 0.1968
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1940
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1940
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1940
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.1940
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1930
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 386ms/step - loss: 0.1930
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1922
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.1922
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1903
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.1903
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1886
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1886
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1915
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 36s 412ms/step - loss: 0.1915
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1886
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.1886
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1865
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.1865
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1863
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.1863
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1859
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.1859
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1863
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.1863
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1872
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.1872
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1880
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1880
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1858
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 36s 412ms/step - loss: 0.1858
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1857
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.1857
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1857
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 368ms/step - loss: 0.1857
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1855
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 370ms/step - loss: 0.1855
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1852
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 367ms/step - loss: 0.1852
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1853
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 367ms/step - loss: 0.1853
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1837
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 370ms/step - loss: 0.1837
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1841
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 36s 408ms/step - loss: 0.1841
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1846
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.1846
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.1830
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1837
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.1837
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1832
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.1832
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.1828
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.1830
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1824
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.1824
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1822
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 37s 418ms/step - loss: 0.1822
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.1828
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1824
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 362ms/step - loss: 0.1824
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 364ms/step - loss: 0.1828
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 361ms/step - loss: 0.1830
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1829
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 362ms/step - loss: 0.1829
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1811
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1811
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1817
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 368ms/step - loss: 0.1817
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 388ms/step - loss: 0.1828
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1810
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 360ms/step - loss: 0.1810
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1811
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 362ms/step - loss: 0.1811
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1810
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 358ms/step - loss: 0.1810
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1825
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 361ms/step - loss: 0.1825
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1817
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 362ms/step - loss: 0.1817
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1811
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 362ms/step - loss: 0.1811
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1811
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 369ms/step - loss: 0.1811
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1819
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 384ms/step - loss: 0.1819
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1810
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1810
# 45/45 [==============================] - 5s 50ms/step

# %%
#Results for J2
RMSE_J2=RMSE_Value(y_testJ2,PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.5555594607500348.

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2993
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 44s 380ms/step - loss: 0.2993
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2944
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2944
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2873
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.2873
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2885
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2885
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2900
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2900
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2864
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 370ms/step - loss: 0.2864
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2861
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 430ms/step - loss: 0.2861
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2875
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2875
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2854
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2854
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2849
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.2849
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2829
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.2829
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2853
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 370ms/step - loss: 0.2853
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2834
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2834
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2805
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.2805
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2788
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 399ms/step - loss: 0.2788
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2780
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2780
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2804
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2804
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2789
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2789
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2745
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2745
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2769
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2769
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2760
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 47s 535ms/step - loss: 0.2760
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2730
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 400ms/step - loss: 0.2730
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2775
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 393ms/step - loss: 0.2775
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2754
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 385ms/step - loss: 0.2754
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2774
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 391ms/step - loss: 0.2774
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2708
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2708
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2728
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 382ms/step - loss: 0.2728
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2750
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2750
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2702
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.2702
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2742
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 36s 411ms/step - loss: 0.2742
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2737
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2737
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2685
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.2685
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2717
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.2717
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2696
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.2696
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2683
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2683
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2665
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 379ms/step - loss: 0.2665
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2691
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 370ms/step - loss: 0.2691
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2681
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 37s 421ms/step - loss: 0.2681
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2676
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2676
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2658
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2658
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2642
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2642
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2668
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 380ms/step - loss: 0.2668
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2665
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2665
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2628
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.2628
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2646
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2646
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2652
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 37s 414ms/step - loss: 0.2652
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2640
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2640
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2627
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2627
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2622
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 370ms/step - loss: 0.2622
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2674
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 362ms/step - loss: 0.2674
# 45/45 [==============================] - 6s 70ms/step

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6111636282161605.

# %%
#Predictions For Forth Junction
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.7006
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 20s 331ms/step - loss: 0.7006
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6944
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 403ms/step - loss: 0.6944
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6903
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 12s 485ms/step - loss: 0.6903
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6897
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 318ms/step - loss: 0.6897
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6876
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 402ms/step - loss: 0.6876
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6927
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 347ms/step - loss: 0.6927
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6906
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 357ms/step - loss: 0.6906
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6890
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 401ms/step - loss: 0.6890
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6817
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 309ms/step - loss: 0.6817
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6830
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 400ms/step - loss: 0.6830
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6835
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 389ms/step - loss: 0.6835
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6837
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 317ms/step - loss: 0.6837
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6849
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 405ms/step - loss: 0.6849
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6792
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 338ms/step - loss: 0.6792
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6774
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 369ms/step - loss: 0.6774
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6784
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 405ms/step - loss: 0.6784
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6831
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 315ms/step - loss: 0.6831
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6763
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 404ms/step - loss: 0.6763
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6779
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 388ms/step - loss: 0.6779
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6779
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 323ms/step - loss: 0.6779
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6774
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 406ms/step - loss: 0.6774
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6724
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 353ms/step - loss: 0.6724
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6729
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 365ms/step - loss: 0.6729
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6766
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 402ms/step - loss: 0.6766
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6693
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 314ms/step - loss: 0.6693
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6683
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 404ms/step - loss: 0.6683
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6680
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 395ms/step - loss: 0.6680
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6696
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 314ms/step - loss: 0.6696
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6628
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 404ms/step - loss: 0.6628
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6620
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 344ms/step - loss: 0.6620
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6582
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 12s 456ms/step - loss: 0.6582
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6588
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 404ms/step - loss: 0.6588
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6459
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 321ms/step - loss: 0.6459
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6564
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 392ms/step - loss: 0.6564
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6438
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 404ms/step - loss: 0.6438
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6309
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 313ms/step - loss: 0.6309
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6262
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 401ms/step - loss: 0.6262
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6127
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 367ms/step - loss: 0.6127
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6130
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 341ms/step - loss: 0.6130
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5991
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 401ms/step - loss: 0.5991
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5874
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 320ms/step - loss: 0.5874
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5775
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 387ms/step - loss: 0.5775
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5707
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 406ms/step - loss: 0.5707
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5560
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 315ms/step - loss: 0.5560
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5463
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 404ms/step - loss: 0.5463
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5459
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 366ms/step - loss: 0.5459
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5531
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 339ms/step - loss: 0.5531
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5341
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 405ms/step - loss: 0.5341
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5487
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 322ms/step - loss: 0.5487
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5262
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 386ms/step - loss: 0.5262
# 13/13 [==============================] - 2s 37ms/step

# %%
#Results for J4
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)
# Out:
# The root mean squared error is 0.9925036096840658.

# %%
# Functions to inverse transforms and Plot comparitive plots
# invert differenced forecast
def inverse_difference(last_ob, value):
    inversed = value + last_ob
    return inversed
#Plotting the comparison
def Sub_Plots2(df_1, df_2,title,m):
    fig, axes = plt.subplots(1, 2, figsize=(18,4), sharey=True,facecolor="#FFEBCD")
    fig.suptitle(title)

    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[m])
    axes[0].set(ylabel ="Prediction")

    pl_2=sns.lineplot(ax=axes[1],data=df_2["Vehicles"],color="#627D78")
    axes[1].set(ylabel ="Orignal")

# %%
# invert the differenced forecast for Junction 1
recover1 = df_N1.Norm[-1412:-1].to_frame()
recover1["Pred"]= PredJ1
Transform_reverssed_J1 = inverse_difference(recover1.Norm, recover1.Pred).to_frame()
Transform_reverssed_J1.columns = ["Pred_Normed"]
#Invert the normalizeation J1
Final_J1_Pred = (Transform_reverssed_J1.values* std_J1) + av_J1
Transform_reverssed_J1["Pred_Final"] =Final_J1_Pred
#Plotting the Predictions with orignals
Sub_Plots2(Transform_reverssed_J1["Pred_Final"], df_1[-1412:-1],"Pridictions And Orignals For Junction 1", 0)

# %%
#Invert the differenced J2
recover2 = df_N2.Norm[-1426:-1].to_frame() #len as per the diff
recover2["Pred"]= PredJ2
Transform_reverssed_J2 = inverse_difference(recover2.Norm, recover2.Pred).to_frame()
Transform_reverssed_J2.columns = ["Pred_Normed"]
Final_J2_Pred = (Transform_reverssed_J2.values* std_J2) + av_J2
Transform_reverssed_J2["Pred_Final"] =Final_J2_Pred
#Plotting the Predictions with orignals
Sub_Plots2(Transform_reverssed_J2["Pred_Final"], df_2[-1426:-1],"Pridictions And Orignals For Junction 2", 1)

# %%
#Invert the differenced J3
recover3 = df_N3.Norm[-1429:-1].to_frame() #len as per the diff
recover3["Pred"]= PredJ3
Transform_reverssed_J3 = inverse_difference(recover3.Norm, recover3.Pred).to_frame()
Transform_reverssed_J3.columns = ["Pred_Normed"]
#Invert the normalizeation J3
Final_J3_Pred = (Transform_reverssed_J3.values* std_J3) + av_J3
Transform_reverssed_J3["Pred_Final"] =Final_J3_Pred
Sub_Plots2(Transform_reverssed_J3["Pred_Final"], df_3[-1429:-1],"Pridictions And Orignals For Junction 3", 2)

# %%
#Invert the differenced J4
recover4 = df_N4.Norm[-404:-1].to_frame()  #len as per the testset
recover4["Pred"]= PredJ4
Transform_reverssed_J4 = inverse_difference(recover4.Norm, recover4.Pred).to_frame()
Transform_reverssed_J4.columns = ["Pred_Normed"]
#Invert the normalizeation J4
Final_J4_Pred = (Transform_reverssed_J4.values* std_J4) + av_J4
Transform_reverssed_J4["Pred_Final"] =Final_J4_Pred
Sub_Plots2(Transform_reverssed_J4["Pred_Final"], df_4[-404:-1],"Pridictions And Orignals For Junction 4", 3)
